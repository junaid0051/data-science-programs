# %% [markdown]
# <a href="https://colab.research.google.com/github/junaid0051/data-science-programs/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("welcome to stone paper")
user_choice=input("Enter stone paper or scissor")
computer_choice="stone"
print("computer choice:",computer_choice)
print("user_choice:",user_choice)
if user_choice==computer_choice:
  print("draw")
elif (
     (user_choice=="stone" and computer_choice=="scissor") or
     (user_choice=="paper" and computer_choice=="stone") or
     (user_choice=="scissor" and computer_choice=="paper")
    ):
      print("you win!")
else:
   print("computer wins!")
# Out:
# welcome to stone paper
# Enter stone paper or scissorpaper
# computer choice: stone
# user_choice: paper
# you win!

# %%
import random
print("welcome to stone paper")
print("Enter stone paper or scissor")
choices=["stone","paper","scissor",]
user_choice=input("user_choice")
computer_choice=random.choice(choices)
print("computer choice:",computer_choice)
print("user_choice:",user_choice)
if user_choice not in choices:
  print("Invalid user input!,enter valid input like stone paper scissor")


if user_choice==computer_choice:
  print("draw")
elif (
     (user_choice=="stone" and computer_choice=="scissor") or
     (user_choice=="paper" and computer_choice=="stone") or
     (user_choice=="scissor" and computer_choice=="paper")
    ):
      print("you win!")
else:
   print("computer wins!")
# Out:
# welcome to stone paper
# Enter stone paper or scissor
# user_choicegbtfgrg
# computer choice: scissor
# user_choice: gbtfgrg
# Invalid user input!,enter valid input like stone paper scissor
# computer wins!

# %%
import random
print("welcome to stone paper")
print("Enter stone paper or scissor")
choices=["stone","paper","scissor",]
user_choice=input("user_choice")
computer_choice=random.choice(choices)
print("computer choice:",computer_choice)
print("user_choice:",user_choice)


while True:


 if user_choice not in choices:
   print("Invalid user input!,enter valid input like stone paper scissor")
   continue

 if user_choice==computer_choice:
   print("draw")
 elif (
      (user_choice=="stone" and computer_choice=="scissor") or
      (user_choice=="paper" and computer_choice=="stone") or
      (user_choice=="scissor" and computer_choice=="paper")
     ):
       print("you win!")
 else:
    print("computer wins!")

 user_choice=input("Do you want to continue the game :yes/no")
 if user_choice!="yes":
  print("thanks for playing")
  break
# Out:
# welcome to stone paper
# Enter stone paper or scissor
